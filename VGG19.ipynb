# %%
from keras.applications.vgg16 import VGG16
from keras.applications.vgg19 import VGG19
from keras.applications.resnet50 import ResNet50
from keras.models import Model
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Input,GRU
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import numpy as np
import tensorflow as tf
from keras.callbacks import EarlyStopping

def build_model(application,model_layer):
    # Load the model
    base_model = application(weights='imagenet', include_top=False, input_shape=(96,96, 3))

    # Make the base model non-trainable
    for layer in base_model.layers:
        layer.trainable = False

    # Define the input shape for our final model
    # The shape should be (num_frames, height, width, channels)
    # Replace num_frames with the number of frames in our video data
    input_shape = (16, 96,96, 3)
    model_input = Input(shape=input_shape)

    # Add a TimeDistributed wrapper to handle the time dimension in the video data
    x = TimeDistributed(base_model)(model_input)

    # Flatten the output
    x = TimeDistributed(Flatten())(x)

    # Add an LSTM layer to handle the sequence of features extracted from the frames
    x = model_layer(256)(x)

    # Add a Dense layer for binary classification
    output = Dense(2, activation='softmax')(x)
    return Model(inputs=model_input, outputs=output)

# %%
features,labels=np.load("Features/features_Own96.npy"),np.load("Features/labels_Own96.npy")

# %%
one_hot_encoded_labels = to_categorical(labels)
features_train, features_test, labels_train, labels_test = train_test_split(features, one_hot_encoded_labels, test_size=0.2,shuffle=True, random_state=42)

# %%
# Create a new model
vgg19_model = build_model(VGG19,LSTM)

# %%
early_stopping_callback = EarlyStopping(monitor = 'val_accuracy', patience = 10, restore_best_weights = True)

# Create ReduceLROnPlateau Callback to reduce overfitting by decreasing learning
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.6,patience=5,min_lr=0.00005,verbose=1)

# Compiling the model 
vgg19_model.compile(loss = 'categorical_crossentropy', optimizer = 'sgd', metrics = ["accuracy"]) 

# Fitting the model 
history = vgg19_model.fit(x = features_train, y = labels_train, epochs = 50, batch_size = 8 ,
                                             shuffle = True, validation_split = 0.2, callbacks = [early_stopping_callback,reduce_lr])
# Out:
# Epoch 1/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 452s 3s/step - accuracy: 0.5667 - loss: 0.7609 - val_accuracy: 0.7219 - val_loss: 0.5595 - learning_rate: 0.0100
# Epoch 2/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 446s 3s/step - accuracy: 0.7262 - loss: 0.5334 - val_accuracy: 0.6938 - val_loss: 0.5439 - learning_rate: 0.0100
# Epoch 3/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 446s 3s/step - accuracy: 0.7658 - loss: 0.4811 - val_accuracy: 0.7781 - val_loss: 0.4390 - learning_rate: 0.0100
# Epoch 4/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 443s 3s/step - accuracy: 0.8016 - loss: 0.4357 - val_accuracy: 0.8281 - val_loss: 0.4029 - learning_rate: 0.0100
# Epoch 5/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 459s 3s/step - accuracy: 0.8472 - loss: 0.3657 - val_accuracy: 0.8469 - val_loss: 0.3601 - learning_rate: 0.0100
# Epoch 6/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 453s 3s/step - accuracy: 0.8387 - loss: 0.3593 - val_accuracy: 0.5969 - val_loss: 0.7943 - learning_rate: 0.0100
# Epoch 7/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 433s 3s/step - accuracy: 0.8296 - loss: 0.3674 - val_accuracy: 0.7063 - val_loss: 0.6202 - learning_rate: 0.0100
# Epoch 8/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 433s 3s/step - accuracy: 0.8346 - loss: 0.3659 - val_accuracy: 0.8594 - val_loss: 0.3175 - learning_rate: 0.0100
# Epoch 9/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 433s 3s/step - accuracy: 0.8552 - loss: 0.3087 - val_accuracy: 0.8656 - val_loss: 0.2848 - learning_rate: 0.0100
# Epoch 10/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 433s 3s/step - accuracy: 0.9069 - loss: 0.2587 - val_accuracy: 0.8469 - val_loss: 0.3390 - learning_rate: 0.0100
# Epoch 11/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 433s 3s/step - accuracy: 0.8993 - loss: 0.2530 - val_accuracy: 0.8813 - val_loss: 0.2832 - learning_rate: 0.0100
# Epoch 12/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 433s 3s/step - accuracy: 0.8937 - loss: 0.2428 - val_accuracy: 0.8906 - val_loss: 0.2997 - learning_rate: 0.0100
# Epoch 13/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 433s 3s/step - accuracy: 0.8931 - loss: 0.2627 - val_accuracy: 0.8656 - val_loss: 0.3106 - learning_rate: 0.0100
# Epoch 14/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 440s 3s/step - accuracy: 0.8564 - loss: 0.3477 - val_accuracy: 0.8281 - val_loss: 0.3744 - learning_rate: 0.0100
# Epoch 15/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 433s 3s/step - accuracy: 0.9043 - loss: 0.2481 - val_accuracy: 0.8531 - val_loss: 0.3272 - learning_rate: 0.0100
# Epoch 16/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9319 - loss: 0.2040
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.005999999865889549.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 437s 3s/step - accuracy: 0.9318 - loss: 0.2040 - val_accuracy: 0.8500 - val_loss: 0.3211 - learning_rate: 0.0100
# Epoch 17/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 435s 3s/step - accuracy: 0.9440 - loss: 0.1779 - val_accuracy: 0.8250 - val_loss: 0.4025 - learning_rate: 0.0060
# Epoch 18/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 439s 3s/step - accuracy: 0.9411 - loss: 0.1643 - val_accuracy: 0.8969 - val_loss: 0.2550 - learning_rate: 0.0060
# Epoch 19/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 447s 3s/step - accuracy: 0.9559 - loss: 0.1441 - val_accuracy: 0.8781 - val_loss: 0.2767 - learning_rate: 0.0060
# Epoch 20/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 464s 3s/step - accuracy: 0.9596 - loss: 0.1272 - val_accuracy: 0.8031 - val_loss: 0.4918 - learning_rate: 0.0060
# Epoch 21/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 441s 3s/step - accuracy: 0.9610 - loss: 0.1206 - val_accuracy: 0.8875 - val_loss: 0.2648 - learning_rate: 0.0060
# Epoch 22/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 437s 3s/step - accuracy: 0.9660 - loss: 0.1123 - val_accuracy: 0.8375 - val_loss: 0.3715 - learning_rate: 0.0060
# Epoch 23/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9745 - loss: 0.1076
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.003600000031292438.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 474s 3s/step - accuracy: 0.9745 - loss: 0.1077 - val_accuracy: 0.8719 - val_loss: 0.3015 - learning_rate: 0.0060
# Epoch 24/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 488s 3s/step - accuracy: 0.9747 - loss: 0.0970 - val_accuracy: 0.9000 - val_loss: 0.2456 - learning_rate: 0.0036
# Epoch 25/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 489s 3s/step - accuracy: 0.9786 - loss: 0.0765 - val_accuracy: 0.8938 - val_loss: 0.2442 - learning_rate: 0.0036
# Epoch 26/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 438s 3s/step - accuracy: 0.9798 - loss: 0.0751 - val_accuracy: 0.9000 - val_loss: 0.2492 - learning_rate: 0.0036
# Epoch 27/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 437s 3s/step - accuracy: 0.9859 - loss: 0.0619 - val_accuracy: 0.9094 - val_loss: 0.2264 - learning_rate: 0.0036
# Epoch 28/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 434s 3s/step - accuracy: 0.9939 - loss: 0.0492 - val_accuracy: 0.8938 - val_loss: 0.2698 - learning_rate: 0.0036
# Epoch 29/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 434s 3s/step - accuracy: 0.9957 - loss: 0.0419 - val_accuracy: 0.8969 - val_loss: 0.2566 - learning_rate: 0.0036
# Epoch 30/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 434s 3s/step - accuracy: 0.9883 - loss: 0.0467 - val_accuracy: 0.8938 - val_loss: 0.2661 - learning_rate: 0.0036
# Epoch 31/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 433s 3s/step - accuracy: 0.9959 - loss: 0.0391 - val_accuracy: 0.9062 - val_loss: 0.2288 - learning_rate: 0.0036
# Epoch 32/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9951 - loss: 0.0355
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0021599999628961085.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 433s 3s/step - accuracy: 0.9951 - loss: 0.0355 - val_accuracy: 0.8969 - val_loss: 0.2404 - learning_rate: 0.0036
# Epoch 33/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 432s 3s/step - accuracy: 0.9975 - loss: 0.0344 - val_accuracy: 0.9031 - val_loss: 0.2211 - learning_rate: 0.0022
# Epoch 34/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 436s 3s/step - accuracy: 0.9985 - loss: 0.0282 - val_accuracy: 0.9031 - val_loss: 0.2293 - learning_rate: 0.0022
# Epoch 35/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 437s 3s/step - accuracy: 0.9995 - loss: 0.0241 - val_accuracy: 0.9156 - val_loss: 0.2250 - learning_rate: 0.0022
# Epoch 36/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 437s 3s/step - accuracy: 0.9977 - loss: 0.0260 - val_accuracy: 0.9031 - val_loss: 0.2367 - learning_rate: 0.0022
# Epoch 37/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 436s 3s/step - accuracy: 0.9993 - loss: 0.0220 - val_accuracy: 0.9094 - val_loss: 0.2301 - learning_rate: 0.0022
# Epoch 38/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9967 - loss: 0.0190
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0012959999497979878.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 437s 3s/step - accuracy: 0.9967 - loss: 0.0190 - val_accuracy: 0.9062 - val_loss: 0.2793 - learning_rate: 0.0022
# Epoch 39/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 433s 3s/step - accuracy: 0.9954 - loss: 0.0203 - val_accuracy: 0.9125 - val_loss: 0.2229 - learning_rate: 0.0013
# Epoch 40/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 433s 3s/step - accuracy: 0.9989 - loss: 0.0154 - val_accuracy: 0.9062 - val_loss: 0.2293 - learning_rate: 0.0013
# Epoch 41/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 433s 3s/step - accuracy: 0.9998 - loss: 0.0161 - val_accuracy: 0.9000 - val_loss: 0.2334 - learning_rate: 0.0013
# Epoch 42/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 433s 3s/step - accuracy: 0.9996 - loss: 0.0149 - val_accuracy: 0.9000 - val_loss: 0.2309 - learning_rate: 0.0013
# Epoch 43/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9994 - loss: 0.0135
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0007775999838486314.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 433s 3s/step - accuracy: 0.9994 - loss: 0.0135 - val_accuracy: 0.9156 - val_loss: 0.2283 - learning_rate: 0.0013
# Epoch 44/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 433s 3s/step - accuracy: 0.9995 - loss: 0.0149 - val_accuracy: 0.9094 - val_loss: 0.2277 - learning_rate: 7.7760e-04
# Epoch 45/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 433s 3s/step - accuracy: 0.9988 - loss: 0.0125 - val_accuracy: 0.8938 - val_loss: 0.2391 - learning_rate: 7.7760e-04

# %%
vgg19_model.save('model_VGG19.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Assuming `predicted_labels` are the predictions of model on the test set
predicted_labels = []
batch_size = 8  # Further reduce this value based on GPU's memory
for i in range(0, features_test.shape[0], batch_size):
    batch_predictions = vgg19_model.predict(features_test[i:i+batch_size], verbose=0)
    batch_predictions = np.argmax(batch_predictions, axis=1)
    predicted_labels.extend(batch_predictions)

predicted_labels = np.array(predicted_labels)
true_labels = np.argmax(labels_test, axis=1)

# Classification Report
print("\nClassification Report of VGG19:")
print(classification_report(true_labels, predicted_labels))

# Confusion Matrix
conf_mat = confusion_matrix(true_labels, predicted_labels)
# print("\nConfusion Matrix of VGG19:")
# print(conf_mat)

# Heatmap for Confusion Matrix
plt.figure(figsize=(10,7))
sns.heatmap(conf_mat, annot=True)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# ROC Curve
fpr, tpr, _ = roc_curve(true_labels, predicted_labels)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve of VGG19')
plt.legend(loc="lower right")
plt.show()
# Out:
# Classification Report of VGG19:
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.89       199
#            1       0.89      0.88      0.89       201
#
#     accuracy                           0.89       400
#    macro avg       0.89      0.89      0.89       400
# weighted avg       0.89      0.89      0.89       400

# %%
plt.figure(figsize=[6,4])
plt.plot(history.history['loss'], 'black', linewidth=2.0)
plt.plot(history.history['val_loss'], 'blue', linewidth=2.0)
plt.legend(['Training Loss', 'Validation Loss'], fontsize=14)
plt.xlabel('Epochs', fontsize=10)
plt.ylabel('Loss', fontsize=10)
plt.title('Loss Curves of VGG19', fontsize=12)
plt.show()
