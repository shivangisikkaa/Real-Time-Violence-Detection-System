# %%
from keras.applications.vgg16 import VGG16
from keras.applications.vgg19 import VGG19
from keras.applications.resnet50 import ResNet50
from keras.models import Model
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Input,GRU
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import numpy as np
import tensorflow as tf
from keras.callbacks import EarlyStopping

def build_model(application,model_layer):
    # Load the model
    base_model = application(weights='imagenet', include_top=False, input_shape=(64, 64, 3))

    # Make the base model non-trainable
    for layer in base_model.layers:
        layer.trainable = False

    # Define the input shape for our final model
    # The shape should be (num_frames, height, width, channels)
    # Replace num_frames with the number of frames in our video data
    input_shape = (16, 64, 64, 3)
    model_input = Input(shape=input_shape)

    # Add a TimeDistributed wrapper to handle the time dimension in the video data
    x = TimeDistributed(base_model)(model_input)

    # Flatten the output
    x = TimeDistributed(Flatten())(x)

    # Add an LSTM layer to handle the sequence of features extracted from the frames
    x = model_layer(256)(x)

    # Add a Dense layer for binary classification
    output = Dense(2, activation='softmax')(x)
    return Model(inputs=model_input, outputs=output)

# %%
features,labels=np.load("Features/features_Own.npy"),np.load("Features/labels_Own.npy")

# %%
one_hot_encoded_labels = to_categorical(labels)
features_train, features_test, labels_train, labels_test = train_test_split(features, one_hot_encoded_labels, test_size=0.2,
                                                                            shuffle=True, random_state=42)

# %%
# Create a new model
ResNet50_model = build_model(ResNet50,LSTM)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 12s 0us/step

# %%
early_stopping_callback = EarlyStopping(monitor = 'val_accuracy', patience = 10, restore_best_weights = True)

# Create ReduceLROnPlateau Callback to reduce overfitting by decreasing learning
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.6,patience=5,min_lr=0.00005,verbose=1)
 
# Compiling the model 
ResNet50_model.compile(loss = 'categorical_crossentropy', optimizer = 'sgd', metrics = ["accuracy"]) 
 
# Fitting the model 
history = ResNet50_model.fit(x = features_train, y = labels_train, epochs = 50, batch_size = 10 ,
                                             shuffle = True, validation_split = 0.2, callbacks = [early_stopping_callback,reduce_lr])
# Out:
# Epoch 1/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 197s 1s/step - accuracy: 0.4837 - loss: 0.8176 - val_accuracy: 0.5562 - val_loss: 0.6797 - learning_rate: 0.0100
# Epoch 2/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 123s 963ms/step - accuracy: 0.5502 - loss: 0.6975 - val_accuracy: 0.4563 - val_loss: 0.7730 - learning_rate: 0.0100
# Epoch 3/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 129s 1s/step - accuracy: 0.5406 - loss: 0.6997 - val_accuracy: 0.5312 - val_loss: 0.6835 - learning_rate: 0.0100
# Epoch 4/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 128s 1s/step - accuracy: 0.5645 - loss: 0.6796 - val_accuracy: 0.5437 - val_loss: 0.7079 - learning_rate: 0.0100
# Epoch 5/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 118s 921ms/step - accuracy: 0.5598 - loss: 0.6789 - val_accuracy: 0.4563 - val_loss: 0.7387 - learning_rate: 0.0100
# Epoch 6/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 747ms/step - accuracy: 0.5675 - loss: 0.6712
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.005999999865889549.
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 119s 929ms/step - accuracy: 0.5676 - loss: 0.6712 - val_accuracy: 0.5500 - val_loss: 0.7086 - learning_rate: 0.0100
# Epoch 7/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 129s 1s/step - accuracy: 0.6031 - loss: 0.6743 - val_accuracy: 0.5781 - val_loss: 0.6692 - learning_rate: 0.0060
# Epoch 8/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 121s 945ms/step - accuracy: 0.5937 - loss: 0.6630 - val_accuracy: 0.5188 - val_loss: 0.6976 - learning_rate: 0.0060
# Epoch 9/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 120s 938ms/step - accuracy: 0.6026 - loss: 0.6567 - val_accuracy: 0.6031 - val_loss: 0.6621 - learning_rate: 0.0060
# Epoch 10/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 132s 1s/step - accuracy: 0.6095 - loss: 0.6539 - val_accuracy: 0.5969 - val_loss: 0.6665 - learning_rate: 0.0060
# Epoch 11/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 124s 968ms/step - accuracy: 0.6022 - loss: 0.6560 - val_accuracy: 0.5688 - val_loss: 0.6910 - learning_rate: 0.0060
# Epoch 12/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 134s 1s/step - accuracy: 0.6280 - loss: 0.6468 - val_accuracy: 0.5750 - val_loss: 0.6757 - learning_rate: 0.0060
# Epoch 13/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 120s 940ms/step - accuracy: 0.6099 - loss: 0.6527 - val_accuracy: 0.5250 - val_loss: 0.7186 - learning_rate: 0.0060
# Epoch 14/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.6058 - loss: 0.6512
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.003600000031292438.
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 127s 991ms/step - accuracy: 0.6059 - loss: 0.6512 - val_accuracy: 0.5969 - val_loss: 0.6631 - learning_rate: 0.0060
# Epoch 15/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 131s 1s/step - accuracy: 0.6261 - loss: 0.6362 - val_accuracy: 0.5531 - val_loss: 0.6885 - learning_rate: 0.0036
# Epoch 16/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 148s 1s/step - accuracy: 0.6229 - loss: 0.6471 - val_accuracy: 0.6125 - val_loss: 0.6557 - learning_rate: 0.0036
# Epoch 17/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 130s 1s/step - accuracy: 0.6053 - loss: 0.6399 - val_accuracy: 0.4875 - val_loss: 0.7895 - learning_rate: 0.0036
# Epoch 18/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 134s 1s/step - accuracy: 0.6573 - loss: 0.6252 - val_accuracy: 0.6000 - val_loss: 0.6639 - learning_rate: 0.0036
# Epoch 19/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 130s 1s/step - accuracy: 0.6611 - loss: 0.6265 - val_accuracy: 0.6219 - val_loss: 0.6609 - learning_rate: 0.0036
# Epoch 20/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 128s 1s/step - accuracy: 0.6563 - loss: 0.6084 - val_accuracy: 0.6250 - val_loss: 0.6571 - learning_rate: 0.0036
# Epoch 21/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 783ms/step - accuracy: 0.6592 - loss: 0.6153
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0021599999628961085.
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 121s 949ms/step - accuracy: 0.6592 - loss: 0.6153 - val_accuracy: 0.5656 - val_loss: 0.7734 - learning_rate: 0.0036
# Epoch 22/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 116s 908ms/step - accuracy: 0.6216 - loss: 0.6324 - val_accuracy: 0.6250 - val_loss: 0.6438 - learning_rate: 0.0022
# Epoch 23/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 127s 990ms/step - accuracy: 0.6704 - loss: 0.6012 - val_accuracy: 0.6219 - val_loss: 0.6411 - learning_rate: 0.0022
# Epoch 24/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 127s 994ms/step - accuracy: 0.6611 - loss: 0.6063 - val_accuracy: 0.6187 - val_loss: 0.6392 - learning_rate: 0.0022
# Epoch 25/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 125s 977ms/step - accuracy: 0.6563 - loss: 0.6126 - val_accuracy: 0.6281 - val_loss: 0.6412 - learning_rate: 0.0022
# Epoch 26/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 115s 897ms/step - accuracy: 0.6827 - loss: 0.5851 - val_accuracy: 0.5594 - val_loss: 0.6795 - learning_rate: 0.0022
# Epoch 27/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 124s 967ms/step - accuracy: 0.6719 - loss: 0.6010 - val_accuracy: 0.6281 - val_loss: 0.6424 - learning_rate: 0.0022
# Epoch 28/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 120s 939ms/step - accuracy: 0.6826 - loss: 0.5890 - val_accuracy: 0.6469 - val_loss: 0.6400 - learning_rate: 0.0022
# Epoch 29/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 829ms/step - accuracy: 0.6484 - loss: 0.6143
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0012959999497979878.
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 130s 1s/step - accuracy: 0.6485 - loss: 0.6142 - val_accuracy: 0.5906 - val_loss: 0.6670 - learning_rate: 0.0022
# Epoch 30/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 133s 1s/step - accuracy: 0.6764 - loss: 0.5981 - val_accuracy: 0.6375 - val_loss: 0.6353 - learning_rate: 0.0013
# Epoch 31/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 126s 987ms/step - accuracy: 0.6767 - loss: 0.5834 - val_accuracy: 0.5750 - val_loss: 0.6923 - learning_rate: 0.0013
# Epoch 32/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 112s 879ms/step - accuracy: 0.6939 - loss: 0.5872 - val_accuracy: 0.6250 - val_loss: 0.6374 - learning_rate: 0.0013
# Epoch 33/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 113s 888ms/step - accuracy: 0.6754 - loss: 0.5909 - val_accuracy: 0.6281 - val_loss: 0.6425 - learning_rate: 0.0013
# Epoch 34/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 113s 881ms/step - accuracy: 0.6800 - loss: 0.5908 - val_accuracy: 0.5156 - val_loss: 0.7475 - learning_rate: 0.0013
# Epoch 35/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 715ms/step - accuracy: 0.6954 - loss: 0.5741
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0007775999838486314.
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 112s 878ms/step - accuracy: 0.6952 - loss: 0.5743 - val_accuracy: 0.6250 - val_loss: 0.6488 - learning_rate: 0.0013
# Epoch 36/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 112s 877ms/step - accuracy: 0.6921 - loss: 0.5807 - val_accuracy: 0.6094 - val_loss: 0.6392 - learning_rate: 7.7760e-04
# Epoch 37/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 118s 925ms/step - accuracy: 0.6985 - loss: 0.5732 - val_accuracy: 0.6187 - val_loss: 0.6515 - learning_rate: 7.7760e-04
# Epoch 38/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 125s 980ms/step - accuracy: 0.7005 - loss: 0.5715 - val_accuracy: 0.6500 - val_loss: 0.6242 - learning_rate: 7.7760e-04
# Epoch 39/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 111s 867ms/step - accuracy: 0.6998 - loss: 0.5592 - val_accuracy: 0.6594 - val_loss: 0.6269 - learning_rate: 7.7760e-04
# Epoch 40/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 111s 870ms/step - accuracy: 0.6847 - loss: 0.5849 - val_accuracy: 0.6594 - val_loss: 0.6220 - learning_rate: 7.7760e-04
# Epoch 41/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 111s 866ms/step - accuracy: 0.6932 - loss: 0.5820 - val_accuracy: 0.6250 - val_loss: 0.6365 - learning_rate: 7.7760e-04
# Epoch 42/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 112s 879ms/step - accuracy: 0.7013 - loss: 0.5878 - val_accuracy: 0.6594 - val_loss: 0.6206 - learning_rate: 7.7760e-04
# Epoch 43/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 111s 866ms/step - accuracy: 0.7009 - loss: 0.5674 - val_accuracy: 0.5219 - val_loss: 0.7369 - learning_rate: 7.7760e-04
# Epoch 44/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 111s 869ms/step - accuracy: 0.6751 - loss: 0.5949 - val_accuracy: 0.5844 - val_loss: 0.6907 - learning_rate: 7.7760e-04
# Epoch 45/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 111s 870ms/step - accuracy: 0.7091 - loss: 0.5550 - val_accuracy: 0.5281 - val_loss: 0.7416 - learning_rate: 7.7760e-04
# Epoch 46/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 118s 927ms/step - accuracy: 0.6854 - loss: 0.5848 - val_accuracy: 0.6250 - val_loss: 0.6374 - learning_rate: 7.7760e-04
# Epoch 47/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 772ms/step - accuracy: 0.6967 - loss: 0.5788
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.0004665599903091788.
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 123s 964ms/step - accuracy: 0.6966 - loss: 0.5787 - val_accuracy: 0.5813 - val_loss: 0.6827 - learning_rate: 7.7760e-04
# Epoch 48/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 111s 872ms/step - accuracy: 0.6832 - loss: 0.5751 - val_accuracy: 0.6625 - val_loss: 0.6134 - learning_rate: 4.6656e-04
# Epoch 49/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 110s 859ms/step - accuracy: 0.7331 - loss: 0.5333 - val_accuracy: 0.6594 - val_loss: 0.6112 - learning_rate: 4.6656e-04
# Epoch 50/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 113s 887ms/step - accuracy: 0.7320 - loss: 0.5550 - val_accuracy: 0.6656 - val_loss: 0.6106 - learning_rate: 4.6656e-04

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import validation_curve
import matplotlib.pyplot as plt
from keras.utils import to_categorical
import seaborn as sns

# Assuming `predicted_labels` are the predictions of our model on the test set
predicted_labels = ResNet50_model.predict(features_test)
predicted_labels = np.argmax(predicted_labels, axis=1)
true_labels = np.argmax(labels_test, axis=1)
# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)

plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d')
plt.title("confusion_matrix of ResNet50")
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.show()

# Classification Report
print("\nClassification Report of ResNet50:")
print(classification_report(true_labels, predicted_labels))

# ROC Curve
fpr, tpr, _ = roc_curve(true_labels, predicted_labels)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve of ResNet50')
plt.legend(loc="lower right")
plt.show()
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 50s 3s/step
# Classification Report of ResNet50:
#               precision    recall  f1-score   support
#
#            0       0.74      0.55      0.63       199
#            1       0.64      0.81      0.72       201
#
#     accuracy                           0.68       400
#    macro avg       0.69      0.68      0.67       400
# weighted avg       0.69      0.68      0.67       400

# %%
plt.figure(figsize=[6,4])
plt.plot(history.history['loss'], 'black', linewidth=2.0)
plt.plot(history.history['val_loss'], 'blue', linewidth=2.0)
plt.legend(['Training Loss', 'Validation Loss'], fontsize=14)
plt.xlabel('Epochs', fontsize=10)
plt.ylabel('Loss', fontsize=10)
plt.title('Loss Curves of ResNet50', fontsize=12)
plt.show()

# %%
# Save the model after training
ResNet50_model.save('model/my_trained_resnet50_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
